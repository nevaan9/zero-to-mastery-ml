# %% [markdown]
# # Unstructured Data: Project
#
# - Always understand the PROCESS that Daniel goes through
# - This process will hold true to many projects to come
#
# link: https://github.com/mrdbourke/zero-to-mastery-ml/blob/wip/section-4-unstructured-data-projects/end-to-end-dog-vision.ipynb
#
# - Daniel did this project in Google Colab (https://colab.research.google.com/)
# - This is because we can utilize googles powerful GPU's to run our ML models
# - HOWEVER
#     - There are limitations to Google Colab
#     - If it disconnects, all the files / variabled in your workspace will be deleted (one example)
#     - Read about it before diving in:
#         - https://research.google.com/colaboratory/faq.html
#
#
# ### Steps to follow for the project:
# 1. Setting up env and getting data ready
#
# - Set up a google colab workspace
# - Connect tp google drive
# - Go to kaggle and upload kaggle dog breeds data to your google drive
# - Go to colab workspace and unzip the data in colab to live in google drive
#     - !unzip "pathToZipFile" -d "pathToDestination"
# - Go through project workflow and write down the steps (Problem def, data, evaluation, features etc)
#     - Same as the supervised learning problem workflow
# - Import tools
#     - Tensorflow (turn data into tensors) --make sure you have Tensorflow latest version!
#     - Google how to import tensor flow
#     - Pick a model from tensorflow hub
#         - Read up on what tensorflow hub is!
#     - Know how to load the latest version of Tensorflow in Colab (hint - use a magic function)
#         - google how to do this
#     - Use a GPU
#         - Know how get this into your colab workspace
#         - It's a matter of clicking on the UI and changing some runtime settings. Google how to do it.
#     - The google colab tutorials (on the site itself - its a colab notebook), is awesome! Floowing some and run the cells
#
# 2. Loading and inspecting the data
#
# - Load the labels.cvs file and do some EDA
#     - How many breeds do we have
#     - How many images per breed to we have
#         - mean?
#         - median?
#             - We look at this because it's mportant to have AT LEAST 10 images per class, but the recommended amount is 100 for the ML model to do well: https://cloud.google.com/vision/automl/object-detection/docs/prepare
# - Load data into TENSORS
# - Know how to VIEW IMAGES in out jupyter notebook
#     - from Ipython.display import Image
# - Put all the filenames (with the path) into an array
#     - Make sure array size is the same as train dir number of files
# - Come up with a way to convert the breed names into numbers
#     - What Daniel did was get an array of all the unique breen names, and create an array of array of each breed where that breed occurs in the the unique breed names array. So if we had ['Lab', 'Dingo', 'Spaniel'] as the unique breeds, and the breeds we have are ['Lab', 'Lab', 'Spaniel', 'Dingo'], the result would be [[1,0,0], [1,0,0], [0,0,1], [0,1,0]]
#     - Can we just convert the string name (make sure all are lowercase) into it's ascii number? Or even a hash? (Nevaan thought)
#
# 3. Create validation set
#
# - This is important because we cannot really train a deeping learning model initially on 10,000+ images. I mean we can but since ML is an iterative process, it would take a crazy amount of time to work on 10,000 in our initial iterations. So lets start with a small number (1000 maybe), if things seem to work well, then increase the training to larger numbers.
# - COOL TRICK IN COLAB - the @param setter. Look it up!
# - After you have decided on the small batch of data you will be working on, further split them into train test samples
#
# 4. Preprocess Images
#
# - Make sure you read the tensorflow docs
#     - https://www.tensorflow.org/tutorials/load_data/images
#     - https://www.tensorflow.org/guide/data
# - Convert image (from it's path) to tnesors
# - NORMALIZE the image values (makes running ML models more efficient)
# - Resize all images into one size
# - Tensorflow likes things in BATCHES
#     - Google what this is
#     - Yaan lecun , jemery howard batch size
#     - Batching is basically taking a batch of images and calulating some stuff on those, and then moving on to the next batch. Yaan Lecun says we need to use 32 as the batch size, but we can explore which is the best for us.
#     - UNDERSTAND AND IMPLEMENT THE TENSORFLOW BATCHES STUFF
#
# 5. Understand Tensor Flowhub and all the other libraries similar to it
#     - These are essentially open source deep learning code we can leverage for our problems
#     - We do not need to re-invent the wheel
# - https://paperswithcode.com/ -- super cool. Research papers with link to github code
# - https://pytorch.org/hub/
# - https://modelzoo.co/
# - https://www.youtube.com/watch?v=oBklltKXtDE&t=173s
#
# - What we wanna do with the current project is JUST DO IT AT FIRST!
#     - Understand what is happening
#     - Then DIVE DEEPER BASED ON THE AREAS YOU THINK ARE INTERESTING!
#     - Just at first though, complete the project and try to understand what the project is doing -- in our case the dog vision project
# - HOMEWORK: Learn how to choose a model from Tensorflow hub
#     - What is an architecture?
#     - How do we know what published models are good vs bad? - is there a star system like npm?
#     - Explore different models and read through them
#         - This is what Daniel used. Read it: https://tfhub.dev/google/imagenet/mobilenet_v2_130_224/classification/4
#
# 6. Putting everything together (Building the model)
# - We can use the Keras apis
#     - What is the difference between sequencial vs functional api?
#     - READ: https://www.tensorflow.org/guide/keras/sequential_model
#     - Learn how to write and setup models in keras!
#     - We are using the following model, so learn how it works:
#         - https://towardsdatascience.com/review-mobilenetv2-light-weight-model-image-classification-8febb490e61c
#         - For multi class classification we use "softmax" as the activation function; for binary classification we use "sigmoid"
#             - https://en.wikipedia.org/wiki/Softmax_function
#             - https://machinelearningmastery.com/how-to-choose-loss-functions-when-training-deep-learning-neural-networks/
#         - https://towardsdatascience.com/a-comprehensive-guide-to-convolutional-neural-networks-the-eli5-way-3bd2b1164a53
# - UNDERSTAND HOW TO INTERPRET THE KERAS OUTPUT TYPE
#
# 7. Evaluating our model
# - Look into KERAS TENSORFLOW CUSTOM CALLBACKS
#     - https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/TensorBoard
#     - Some example callbacks are TensorBoard (show progress of our model training) and Early Stopping Callback (prevent over fitting)
# - PREVENTING OVERFITTING (Early stopping callback)
#     - You dont wanna oveerfit (memorize), because it prevents our model from generalizing very well!
# - What is number of Epochs?
#     - Research!
#     - Essentially number of passes of the data we want to do
# - After training your model...
#     - QUESTION: What happens of the model is overfitting? (i.e the accuracy that the training dataset has is higher than the validation dataset.) - HOW DO WE PREVENT THIS?
#         - Note: Overfitting to begin with is a GOOD THING
#         - We can evaluate this with our tensorboard logs
#             - Know how to get the tensorboard dashboard up and running - PRETTY COOL FEATURE!
#             - Access the logs directory and visualize the contents
#         -  One way to prevent overfitting is by USING MORE DATA!
#
# 8. Making Predictions
# - Know what the model output shape is (we will usually name it predictions)
# - In Daniels example it was a 200 x 120 matrix
#     - This is because he passed 200 values to be predicted
#     - The prediction output returns all those 200 values with 120 values that add up to 1 (these are the prediction probabilites aka confidence intervals)
#         - why 120? Because we had 120 breeds that the prediction can be (unique_breeds array)
#         - So the prediction will be the highest probability in the returned 'prediction' array; The index where that highest probability is, will be the index where our prediction will be in unique_breeds array

# %% [markdown]
# ### Finishing Dog Vision: Where to next?
# Woah! What an effort. If you've made it this far, you've just gone end-to-end on a multi-class image classification problem. This is the same style of problem self-driving cars have, except with different data.
#
# - You should be proud of yourself. Consider finishing this project a momentum builder for getting started with your next deep learning projects.
#
# - If you're looking for some ideas, you've got plenty of options.
#
# - You could try to improve the full model we trained in this notebook in a few ways (there are a fair few options). Since our early experiment (using only 1000 images) hinted at our model overfitting (the results on the training set far outperformed the results on the validation set), one goal going forward would be to try and prevent it.
#
# - Trying another model from TensorFlow Hub - Perhaps a different model would perform better on our dataset. One option would be to experiment with a different pre-trained model from TensorFlow Hub or look into the tf.keras.applications module. (https://www.tensorflow.org/api_docs/python/tf/keras/applications)
#
# - Data augmentation - Take the training images and manipulate (crop, resize) or distort them (flip, rotate) to create even more training data for the model to learn from. Check out the TensorFlow images documentation for a whole bunch of functions you can use on images. A great idea would be to try and replicate the techniques in this example cat vs. dog image classification notebook for our dog breeds problem. (https://bair.berkeley.edu/blog/2019/06/07/data_aug/), (https://www.tensorflow.org/api_docs/python/tf/image), (https://github.com/google/eng-edu/blob/main/ml/pc/exercises/image_classification_part2.ipynb)
#
# - Fine-tuning - The model we used in this notebook was directly from TensorFlow Hub, we took what it had already learned from another dataset (ImageNet) and applied it to our own. Another option is to use what the model already knows and fine-tune this knowledge to our own dataset (pictures of dogs). This would mean all of the patterns within the model would be updated to be more specific to pictures of dogs rather than general images. (https://www.tensorflow.org/hub/tf2_saved_model#fine-tuning)
#
# If you're after more, one of the best ways to find out something is to search for something like:
#
# "How to improve a TensorFlow 2.x image classification model?"
#
# "TensorFlow 2.x image classification best practices"
#
# "Transfer learning for image classification with TensorFlow 2.x"
#
# "Deep learning project examples with TensorFlow 2.x"
#
# - The TensorFlow developers have even put together a massive compilation of all of their favourite TensorFlow and machine learning resources. (https://www.tensorflow.org/resources/learn-ml)
#
# When you see an example you think might be beyond your reach (because it looks too complicated), remember if in doubt, run the code. Try and reproduce what you see. This is the best way to get hands-on and build your own knowledge.
#
# No one starts out knowing how to do everything single thing. They just get better are knowing what to look for.
#
# And remember, if you have any questions, don't forget to send @mrdbourke or @AndreiNeagoie a message on Twitter or in the Discord chat!
